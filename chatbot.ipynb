# %% [markdown]
# <a href="https://colab.research.google.com/github/somebloke25/chatbotwithcontext/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install anthropic python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 478.8/478.8 kB 7.7 MB/s eta 0:00:00
# ...

# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
# Out:
# True

# %%
def add_user_message(messages, new_message):
  nm= {"role":"user" , "content": new_message}
  messages.append(nm)

def add_assistant_message(messages, new_message):
  nm = {"role":"assistant" ,"content": new_message}
  messages.append(nm)

def chat(messages):
  response = client.messages.create(
      model=model,
      max_tokens=1000,
      messages=messages

  )
  #print (response)
  return response.content[0].text

# %%
#create an empty messages
messages=[]
client=Anthropic()
model="claude-sonnet-4-0"
question="what is 2+2"

add_user_message(messages,question)
#print (messages)

fq=chat(messages)
print(fq)
add_assistant_message (messages,fq)

add_user_message(messages,"add 5 more to it ")
final_answer = chat(messages)
print (messages)
print (final_answer)
# Out:
# 2 + 2 = 4
# [{'role': 'user', 'content': 'what is 2+2'}, {'role': 'assistant', 'content': '2 + 2 = 4'}, {'role': 'user', 'content': 'add 5 more to it '}]
# 4 + 5 = 9

# %%
messages=[]
client=Anthropic()
model="claude-sonnet-4-0"

while True:

  first_question=input(">    ")
  print (first_question)

  add_user_message(messages,first_question)
  first_answer = chat(messages)
  print (first_answer)
  add_assistant_message(messages,first_answer)
# Out:
# >    what is 5+5
# what is 5+5
# 5 + 5 = 10
# >    add 7 to it
# add 7 to it
# 10 + 7 = 17
# >    add 100 to it
# add 100 to it
# 17 + 100 = 117
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12893/945837897.py in <cell line: 0>()
#       5 while True:
#       6
# ----> 7   first_question=input(">    ")
#       8   print (first_question)
#       9
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...
